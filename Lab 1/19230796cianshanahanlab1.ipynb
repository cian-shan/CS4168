# %% [markdown]
# To compare the marriage status of those who are over the age of 40 across all job types

# %% [markdown]
# Notable Metrics
#
# Convetional
# 1. Marital
# 2. Job
#
# Numerical
# 1. Age
#
# Remove all individuals under 40
# Do a basic count of all marital statuses

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\cians\OneDrive - University of Limerick\4th Year - Computer Systems\Sem 2\CS4168 - Data Mining\bank.csv')

# %%
df2 = df[df['age'] >= 40 ]

# %%
df2['age'].value_counts()
# Out:
# 46.0    54
# 40.0    50
# 45.0    45
# 43.0    43
# 41.0    43
# 49.0    41
# 48.0    41
# 54.0    40
# 47.0    40
# 60.0    38
# 53.0    35
# 42.0    35
# 56.0    34
# 57.0    34
# 51.0    32
# 52.0    32
# 44.0    31
# 58.0    28
# 55.0    24
# 59.0    22
# 50.0    22
# 61.0    18
# 62.0    15
# 64.0    15
# 63.0    15
# 68.0     9
# 67.0     9
# 72.0     8
# 77.0     8
# 71.0     7
# 80.0     6
# 66.0     6
# 65.0     6
# 69.0     6
# 75.0     6
# 78.0     5
# 74.0     5
# 70.0     4
# 82.0     3
# 84.0     3
# 93.0     2
# 86.0     2
# 76.0     2
# 73.0     2
# 81.0     2
# 79.0     1
# Name: age, dtype: int64

# %%
df['job'].hist(bins=50)
plt.xlabel('job')
plt.ylabel('count')
plt.tick_params(axis='x', which='major', labelsize=4)
plt.show()

# %%
sns.countplot(data=df2, x='job', hue='marital')
plt.tick_params(axis='x', which='major', labelsize=5)

# %%
#correlation matrix
sns.heatmap(df.corr());

# %% [markdown]
# from these comparisons I can draw the conclusion that
